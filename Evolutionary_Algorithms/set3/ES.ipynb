# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from functools import partial, reduce

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from es import *
from functions import *
from plot import *

# %%
results = {}

# %% [markdown]
# # Unconstrained Global Optimization

# %%
problem_name = 'bohachevsky_1'
params = {
    'T': 100,
    'mu': 100,
    'lambd': 100,
    'chromosome_len': 2,
    'K': 0.6,
    'F': bohachevsky_function,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.02560210 min:   0.10006396 mean:   1.11784183 max:   1.91761271 std:   0.41381855
#  10     0.03399205 min:   0.00000202 mean:   0.00091111 max:   0.00172759 std:   0.00050867
#  20     0.04069805 min:   0.00000025 mean:   0.00001732 max:   0.00003630 std:   0.00001103
#  30     0.05100584 min:   0.00000000 mean:   0.00000019 max:   0.00000039 std:   0.00000011
#  40     0.06148696 min:   0.00000000 mean:   0.00000001 max:   0.00000001 std:   0.00000000
#  50     0.06778407 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  60     0.07345915 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  70     0.07915187 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  80     0.08454633 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  90     0.08992863 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  99     0.09481716 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
# Results for bohachevsky_1
# Min cost: 0.0
# costs mean: 0.0014445317707410842
# costs std: 0.01030163941587664

# %%
problem_name = 'griewank_1'
params = {
    'T': 3000,
    'mu': 500,
    'lambd': 1000,
    'domain': (-600, 600),
    'chromosome_len': 40,
    'K': 0.6,
    'F': griewank,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.01101875 min: 662.37121276 mean: 956.58409408 max: 1066.82955041 std:  82.84737026
# 300     1.42799973 min:  19.22525781 mean:  19.28088645 max:  19.29256351 std:   0.00996179
# 600     2.85499692 min:   1.55351828 mean:   1.56089640 max:   1.56312756 std:   0.00185178
# 900     4.21769452 min:   0.66671277 mean:   0.70874577 max:   0.71752312 std:   0.00777508
# 1200     5.58893919 min:   0.04175922 mean:   0.04188119 max:   0.04190558 std:   0.00002066
# 1500     6.95368099 min:   0.03689100 mean:   0.03731591 max:   0.03742992 std:   0.00009830
# 1800     8.32136559 min:   0.02537654 mean:   0.02538090 max:   0.02538201 std:   0.00000102
# 2100     9.68872476 min:   0.02462199 mean:   0.02462203 max:   0.02462204 std:   0.00000001
# 2400    11.07432604 min:   0.02461530 mean:   0.02461531 max:   0.02461532 std:   0.00000000
# 2700    12.44101405 min:   0.02461064 mean:   0.02461064 max:   0.02461064 std:   0.00000000
# 2999    13.86570859 min:   0.02461021 mean:   0.02461021 max:   0.02461021 std:   0.00000000
# Results for griewank_1
# Min cost: 0.024610211174046714
# costs mean: 10.421531157496306
# costs std: 54.105680127317896

# %%
problem_name = 'griewank_1'
params = {
    'T': 5000,
    'mu': 1000,
    'lambd': 2000,
    'domain': (-600, 600),
    'chromosome_len': 80,
    'K': 1,
    'F': griewank,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.04022241 min: 1732.05665664 mean: 2112.59827410 max: 2254.90224933 std: 110.08587603
# 500    11.34794068 min: 134.99883513 mean: 135.37390082 max: 135.48245545 std:   0.09215893
# 1000    22.22097564 min: 113.19396512 mean: 113.99478908 max: 114.10784758 std:   0.10725188
# 1500    33.06509733 min:  49.56836301 mean:  49.57156113 max:  49.57262607 std:   0.00087047
# 2000    43.83854771 min:  49.30998384 mean:  49.31307516 max:  49.31382710 std:   0.00067023
# 2500    54.68123364 min:  39.77928489 mean:  39.78293167 max:  39.78391997 std:   0.00081651
# 3000    65.78595614 min:  39.52308258 mean:  39.52309927 max:  39.52310305 std:   0.00000334
# 3500    76.60524011 min:   1.49580381 mean:   1.49719562 max:   1.49770240 std:   0.00040497
# 4000    87.44285607 min:   1.39609662 mean:   1.39611869 max:   1.39612397 std:   0.00000489
# 4500    98.12439013 min:   1.08958457 mean:   1.08964288 max:   1.08965732 std:   0.00001255
# 4999   108.96341586 min:   1.08181202 mean:   1.08181720 max:   1.08181862 std:   0.00000123
# Results for griewank_1
# Min cost: 1.0818120188810108
# costs mean: 63.81897192567656
# costs std: 130.2885169537535

# %%
problem_name = 'griewank_1'
params = {
    'T': 50000,
    'mu': 200,
    'lambd': 400,
    'domain': (-600, 600),
    'chromosome_len': 200,
    'K': 0.8,
    'F': griewank,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.01704383 min: 4933.77131999 mean: 5532.23422280 max: 5729.57994594 std: 173.05624978
# 5000    40.79871082 min: 330.67141267 mean: 330.68415890 max: 330.68627392 std:   0.00203688
# 10000    84.13299036 min: 188.93374576 mean: 188.93615086 max: 188.93652509 std:   0.00037581
# 15000   125.69342709 min: 170.44270397 mean: 170.50195324 max: 170.51643714 std:   0.01334761
# 20000   168.80911231 min: 160.65346523 mean: 160.65388968 max: 160.65406589 std:   0.00014811
# 25000   212.38352323 min: 160.28273275 mean: 160.28279485 max: 160.28281724 std:   0.00001800
# 30000   254.52200389 min: 154.57101881 mean: 154.57102104 max: 154.57102166 std:   0.00000061
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-128-517978942df3> in <module>
#       9     'F': griewank,
#      10 }
# ---> 11 results[problem_name] =  es_mu_plus_lambda(**params)
#      12 plot_es_results(problem_name, **results[problem_name])
#
# ~/Notebooks/Evolutionary_Algorithms/set3/es.py in es_mu_plus_lambda(mu, lambd, chromosome_len, T, K, F, domain)
#      72         children = population[list(parent_indices), :].copy()
#      73
# ---> 74         mutation(children, t, t0, chromosome_len, lambd)
#      75         children_objective_values = eval_obj_function__bulk(F, children)
#      76
#
# ~/Notebooks/Evolutionary_Algorithms/set3/es.py in mutation(population, t, t0, chromosome_len, size)
#      28     sigmas *= np.exp(eps0 + eps1)
#      29
# ---> 30     xs += np.random.randn(*xs.shape) * (sigmas)
#      31
#      32
#
# KeyboardInterrupt:

# %%
problem_name = 'rastrigin_function_1'
params = {
    'T': 1000,
    'mu': 2000,
    'lambd': 6000,
    'chromosome_len': 10,
    'domain': (-5.12, 5.12),
    'K': 10,
    'F': rastrigin,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.01671720 min:  74.73735395 mean: 154.26705845 max: 179.42625062 std:  19.61808174
# 100     1.11882019 min:   0.00012932 mean:   0.00013027 max:   0.00013071 std:   0.00000021
# 200     2.18376899 min:   0.00012169 mean:   0.00012169 max:   0.00012169 std:   0.00000000
# Results for rastrigin_function_1
# Min cost: 0.0
# costs mean: 0.636051669165
# costs std: 4.59808573981

# %%
problem_name = 'rastrigin_function_1'
params = {
    'T': 8000,
    'mu': 10000,
    'lambd': 20000,
    'chromosome_len': 20,
    'domain': (-5.12, 5.12),
    'K': 5,
    'F': rastrigin,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])

# %%
problem_name = 'rastrigin_function_1'
plot_es_results(problem_name, **results[problem_name])
# Out:
# Results for rastrigin_function_1
# Min cost: 0.0
# costs mean: 1.75083757025
# costs std: 8.43629964489

# %%
problem_name = 'rastrigin_function_2'
params = {
    'T': 2000,
    'mu': 1500,
    'lambd': 3000,
    'chromosome_len': 30,
    'domain': (-5.12, 5.12),
    'K': 15,
    'F': rastrigin,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.02276707 min: 338.77341587 mean: 511.39007761 max: 559.80463459 std:  36.91895595
# 200     2.97774887 min:  35.60879706 mean:  35.71855794 max:  35.80425295 std:   0.05800702
# 400     5.78770900 min:  32.52441900 mean:  32.52441900 max:  32.52441900 std:   0.00000000
# 600     8.58029294 min:  30.93514310 mean:  30.93514310 max:  30.93514310 std:   0.00000000
# 800    11.37171102 min:  29.50055471 mean:  29.50055471 max:  29.50055471 std:   0.00000000
# 1000    14.13347602 min:  29.49965406 mean:  29.50025832 max:  29.50025934 std:   0.00001774
# Results for rastrigin_function_1
# Min cost: 0.0
# costs mean: 25.3861740957
# costs std: 38.1149445837

# %%
problem_name = 'rastrigin_function_3'
params = {
    'T': 10000,
    'mu': 10000,
    'lambd': 20000,
    'chromosome_len': 30,
    'domain': (-5.12, 5.12),
    'K': 4,
    'F': rastrigin,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])

# %%
problem_name = 'rastrigin_function_3'
plot_es_results(problem_name, **results[problem_name])
# Out:
# Results for rastrigin_function_3
# Min cost: 0.0
# costs mean: 3.19563197499
# costs std: 15.6736596354

# %%
problem_name = 'schwefel_function_1'
params = {
    'T': 10000,
    'mu': 10000,
    'lambd': 20000,
    'chromosome_len': 10,
    'domain': (-500, 500),
    'K': 0.5,
    'F': schwefel,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])

# %%
problem_name = 'schwefel_function_1'
plot_es_results(problem_name, **results[problem_name])
# Out:
# Results for schwefel_function_1
# Min cost: 0.0
# costs mean: 14.9761277328
# costs std: 93.8625956476

# %%
problem_name = 'schwefel_function_2'
params = {
    'T': 50000,
    'mu': 10000,
    'lambd': 20000,
    'chromosome_len': 20,
    'domain': (-500, 500),
    'K': 0.6,
    'F': schwefel,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])

# %%
problem_name = 'schwefel_function_2'
plot_es_results(problem_name, **results[problem_name])
# Out:
# Results for schwefel_function_2
# Min cost: 0.0
# costs mean: 33.7208542437
# costs std: 285.747809523

# %%
problem_name = 'schwefel_function_3'
params = {
    'T': 50000,
    'mu': 10000,
    'lambd': 20000,
    'chromosome_len': 30,
    'domain': (-500, 500),
    'K': 0.6,
    'F': schwefel,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])

# %%
problem_name = 'schwefel_function_3'
plot_es_results(problem_name, **results[problem_name])
# Out:
# Results for schwefel_function_3
# Min cost: 4422.52063626
# costs mean: 4424.91264432
# costs std: 60.800500738

# %%
problem_name = 'zakharov_function_1'
params = {
    'T': 1000,
    'mu': 500,
    'lambd': 1000,
    'chromosome_len': 30,
    'domain': (-5, 10),
    'K': 0.6,
    'F': zakharov,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.00656199 min: 277.63156253 mean: 20493771251.16044998 max: 54612228277.85543060 std: 17106182442.81749344
# 100     0.44686890 min:  83.14717111 mean:  93.55865994 max:  95.68196541 std:   1.80973477
# 200     0.88629293 min:  36.53469094 mean:  37.38179804 max:  37.54143915 std:   0.14187857
# 300     1.32573509 min:  21.93374227 mean:  22.89338980 max:  23.06153461 std:   0.14734895
# 400     1.76518202 min:  19.23266721 mean:  19.38263873 max:  19.41926096 std:   0.03203754
# 500     2.20490098 min:  16.69593995 mean:  16.91315884 max:  16.96001186 std:   0.04441039
# 600     2.64447808 min:  15.10972273 mean:  15.18067898 max:  15.19253893 std:   0.01027889
# 700     3.08407307 min:   3.98782626 mean:   4.05990174 max:   4.08146093 std:   0.01686973
# 800     3.52376890 min:   1.66611542 mean:   2.03071889 max:   2.08710185 std:   0.04459001
# 900     3.96315908 min:   0.22083278 mean:   0.22771792 max:   0.23001931 std:   0.00181745
# 999     4.39835501 min:   0.13793325 mean:   0.14175469 max:   0.14241994 std:   0.00076076
# Results for zakharov_function_1
# Min cost: 0.137933254591
# costs mean: 31.812206936
# costs std: 51.1810998459

# %%
problem_name = 'zakharov_function_2'
params = {
    'T': 5000,
    'mu': 1500,
    'lambd': 3000,
    'chromosome_len': 40,
    'domain': (-5, 10),
    'K': 1,
    'F': zakharov,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.02308989 min: 843.88599354 mean: 257198169487.21658325 max: 578139360708.68200684 std: 167085936757.35876465
# 500     8.40706801 min:  18.55818994 mean:  19.97882806 max:  20.11454059 std:   0.16967334
# 1000    16.78813887 min:   4.74611738 mean:   4.74932148 max:   4.74995503 std:   0.00046301
# 1500    25.16663408 min:   3.82922282 mean:   3.83092102 max:   3.83114373 std:   0.00022264
# 2000    33.55239487 min:   3.59078758 mean:   3.59085001 max:   3.59086877 std:   0.00001421
# 2500    41.93627596 min:   0.92101117 mean:   0.92194064 max:   0.92207596 std:   0.00014307
# 3000    50.31760287 min:   0.79821438 mean:   0.79825466 max:   0.79826091 std:   0.00000607
# 3500    58.70038891 min:   0.09076802 mean:   0.09090615 max:   0.09093370 std:   0.00002092
# 4000    67.08289289 min:   0.08607708 mean:   0.08611923 max:   0.08612575 std:   0.00000552
# 4500    75.46704507 min:   0.06618804 mean:   0.06619203 max:   0.06619354 std:   0.00000101
# 4999    83.83674407 min:   0.06266212 mean:   0.06266719 max:   0.06266760 std:   0.00000045
# Results for zakharov_function_1
# Min cost: 0.0626621158018
# costs mean: 14.5196896633
# costs std: 52.3859642941

# %%
problem_name = 'zakharov_function_3'
params = {
    'T': 10000,
    'mu': 15000,
    'lambd': 30000,
    'chromosome_len': 60,
    'domain': (-5, 10),
    'K': 1.5,
    'F': zakharov,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])

# %%
problem_name = 'zakharov_function_3'
plot_es_results(problem_name, **results[problem_name])
# Out:
# Results for zakharov_function_3
# Min cost: 4.10811815954
# costs mean: 45.8223492606
# costs std: 1155.85609525

# %%
problem_name = 'zakharov_function_3'
params = {
    'T': 60000,
    'mu': 10000,
    'lambd': 20000,
    'chromosome_len': 60,
    'domain': (-5, 10),
    'K': 1.5,
    'F': zakharov,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.29190016 min: 48077714.19440518 mean: 7958335706967.31054688 max: 15995414131652.32226562 std: 4549344341330.73437500

# %%
problem_name = 'zakharov_function_3'
plot_es_results(problem_name, **results[problem_name])

# %%
problem_name = 'dixon_and_price_function_1'
params = {
    'T': 2000,
    'mu': 500,
    'lambd': 1000,
    'chromosome_len': 30,
    'domain': (-10, 10),
    'K': 0.5,
    'F': dixon_and_price,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.07955003 min: 1033855.09494336 mean: 2379394.60819963 max: 2999023.13764726 std: 445036.33196657
# 200     7.45759606 min:  52.74763255 mean:  55.05169004 max:  55.40749003 std:   0.31784609
# 400    14.84059191 min:   6.94995835 mean:   7.24663482 max:   7.33240984 std:   0.07474104
# 600    22.21699786 min:   2.68699809 mean:   2.70108662 max:   2.70552049 std:   0.00364641
# 800    29.59938002 min:   1.57705892 mean:   1.62995824 max:   1.63818945 std:   0.00882060
# 1000    36.97406197 min:   0.57035612 mean:   0.57761989 max:   0.58013642 std:   0.00201289
# 1200    44.35105586 min:   0.50611704 mean:   0.50635651 max:   0.50641611 std:   0.00005470
# 1400    51.72362804 min:   0.50013135 mean:   0.50013221 max:   0.50013243 std:   0.00000018
# 1600    59.10279989 min:   0.50004972 mean:   0.50005710 max:   0.50005978 std:   0.00000210
# 1800    66.48562789 min:   0.50000057 mean:   0.50000058 max:   0.50000058 std:   0.00000000
# 1999    73.82379603 min:   0.50000052 mean:   0.50000052 max:   0.50000052 std:   0.00000000
# Results for dixon_and_price_function_1
# Min cost: 0.500000517566
# costs mean: 4031.95201138
# costs std: 43818.3639523

# %%
problem_name = 'dixon_and_price_function_1'
params = {
    'T': 2000,
    'mu': 1000,
    'lambd': 2000,
    'chromosome_len': 50,
    'domain': (-10, 10),
    'K': 0.7,
    'F': dixon_and_price,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.16855597 min: 4544538.38487944 mean: 7641311.44265009 max: 9069837.43785219 std: 1004176.91989169
# 200    22.15611410 min: 4846.67354791 mean: 5564.72679104 max: 5738.35361042 std: 155.24023238
# 400    44.14276695 min:  85.27796312 mean:  88.09231523 max:  88.88784087 std:   0.67845595
# 600    66.13229799 min:  26.53587441 mean:  26.84308960 max:  26.90503615 std:   0.05794918
# 800    88.06753707 min:  14.71820038 mean:  14.80094215 max:  14.81925188 std:   0.01610065
# 1000   110.02043295 min:  12.08253195 mean:  12.22011958 max:  12.25929350 std:   0.03296678
# 1200   131.97110200 min:  10.10648574 mean:  10.11332417 max:  10.11494396 std:   0.00135841
# 1400   153.91611314 min:   9.69510821 mean:   9.69990322 max:   9.70053885 std:   0.00060684
# 1600   175.91673112 min:   8.88346948 mean:   8.90726459 max:   8.91359557 std:   0.00543658
# 1800   197.90800309 min:   8.72262483 mean:   8.72498832 max:   8.72543884 std:   0.00039407
# 1999   219.75962996 min:   8.66117174 mean:   8.66163728 max:   8.66174631 std:   0.00009331
# Results for dixon_and_price_function_1
# Min cost: 8.66117173773
# costs mean: 30712.3461134
# costs std: 238989.125024

# %%
problem_name = 'dixon_and_price_function_1'
params = {
    'T': 8000,
    'mu': 5000,
    'lambd': 10000,
    'chromosome_len': 50,
    'domain': (-10, 10),
    'K': 0.7,
    'F': dixon_and_price,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.80461478 min: 3505443.90230725 mean: 7553481.65233317 max: 8988101.53236462 std: 1068439.92510259

# %%
problem_name = 'dixon_and_price_function_1'
plot_es_results(problem_name, **results[problem_name])
# Out:
# Results for dixon_and_price_function_1
# Min cost: 7.96303710978
# costs mean: 5069.92848111
# costs std: 87206.8676733

# %%
problem_name = 'dixon_and_price_function_1'
params = {
    'T': 3000,
    'mu': 2000,
    'lambd': 4000,
    'chromosome_len': 50,
    'domain': (-10, 10),
    'K': 0.7,
    'F': dixon_and_price,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.32424188 min: 2872043.19941104 mean: 7503324.91498076 max: 8857024.49916724 std: 1059403.25638566
# 300    66.04679680 min: 328.14706146 mean: 353.36723346 max: 358.71217722 std:   4.55283745
# 600   131.88423800 min:  47.31173694 mean:  47.51597507 max:  47.57407021 std:   0.04745032
# 900   197.58899498 min:  40.39267568 mean:  40.47063079 max:  40.48541040 std:   0.01338430
# 1200   263.29423380 min:  37.15596476 mean:  37.16365871 max:  37.16540857 std:   0.00150642
# 1500   329.03361392 min:  35.39438683 mean:  35.39708896 max:  35.39775119 std:   0.00054971
# 1800   394.82780480 min:  12.45143392 mean:  13.17198201 max:  13.34823471 std:   0.14570716
# 2100   460.73342395 min:   9.81501078 mean:   9.81584688 max:   9.81600365 std:   0.00013985
# 2400   526.55531597 min:   9.27745723 mean:   9.27779064 max:   9.27784977 std:   0.00005292
# 2700   592.35468984 min:   9.20770275 mean:   9.20798580 max:   9.20804160 std:   0.00005255
# 2999   657.95297098 min:   8.88478288 mean:   8.90095255 max:   8.90428590 std:   0.00303834
# Results for dixon_and_price_function_1
# Min cost: 8.88478288452
# costs mean: 18526.3861983
# costs std: 144086.288097

# %% [markdown]
# # Constrained Global Optimization

# %%
print(results.keys())
