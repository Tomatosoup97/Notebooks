# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from functools import partial, reduce

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from es import *
from functions import *
from plot import *

# %%
results = {}

# %%
problem_name = 'bohachevsky_1'
params = {
    'T': 100,
    'mu': 100,
    'lambd': 100,
    'chromosome_len': 2,
    'K': 0.6,
    'F': bohachevsky_function,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.00134015 min:   0.10724924 mean:   1.24214153 max:   2.05496555 std:   0.46558915
#  10     0.00770521 min:   0.03013037 mean:   0.25751156 max:   0.43795792 std:   0.11484737
#  20     0.01333904 min:   0.00006122 mean:   0.01110048 max:   0.02918536 std:   0.00793333
#  30     0.01870608 min:   0.00000472 mean:   0.00022780 max:   0.00043420 std:   0.00013178
#  40     0.02410412 min:   0.00000000 mean:   0.00000823 max:   0.00001744 std:   0.00000497
#  50     0.02950501 min:   0.00000000 mean:   0.00000051 max:   0.00000098 std:   0.00000028
#  60     0.03487301 min:   0.00000000 mean:   0.00000005 max:   0.00000009 std:   0.00000003
#  70     0.04026413 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  80     0.04559898 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  90     0.05097198 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  99     0.05582619 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
# Results for bohachevsky_1
# Min cost: 1.11022302463e-16
# costs mean: 0.00792392867581
# costs std: 0.024776776388

# %%
problem_name = 'dixon_and_price_function_1'
params = {
    'T': 3000,
    'mu': 1000,
    'lambd': 2000,
    'chromosome_len': 30,
    'domain': (-10, 10),
    'K': 0.5,
    'F': dixon_and_price_function,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.09004593 min: 672039.80788064 mean: 2523488.95930982 max: 3160092.27776628 std: 469573.14069364
# 300    17.91657400 min: 29158.26927920 mean: 29311.24092845 max: 29353.78407576 std:  35.91556944
# 600    35.48079801 min: 23554.21856627 mean: 23596.53719490 max: 23606.88708913 std:   8.60295476
# 900    53.01274300 min: 21125.87246733 mean: 21160.74562786 max: 21170.09114382 std:   7.73357560
# 1200    70.79056096 min: 19865.12438928 mean: 19893.85749148 max: 19899.76011323 std:   5.07098705
# 1500    88.62608194 min: 18838.16901021 mean: 18850.50463272 max: 18854.38229147 std:   3.14615398
# 1800   106.19222808 min: 17934.23936958 mean: 17950.84026190 max: 17955.26200083 std:   3.77998554
# 2100   123.74374104 min: 17065.86079201 mean: 17079.84488379 max: 17083.62094018 std:   3.20366105
# 2400   141.28374386 min: 15936.82201649 mean: 15948.85336612 max: 15952.02715882 std:   2.60522387
# 2700   158.81323600 min: 14516.21839277 mean: 14538.98055928 max: 14545.53044245 std:   4.93689762
# 2999   176.30358195 min: 12668.52406905 mean: 12712.49491346 max: 12725.72092523 std:  10.50376926
# Results for dixon_and_price_function_1
# Min cost: 12668.524069
# costs mean: 22309.5696139
# costs std: 23166.9175611

# %%
problem_name = 'dixon_and_price_function_1'
params = {
    'T': 2000,
    'mu': 200,
    'lambd': 400,
    'chromosome_len': 30,
    'domain': (-10, 10),
    'K': 0.5,
    'F': dixon_and_price_function,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.02496910 min: 1100609.77740556 mean: 2442011.68359812 max: 3152363.95330908 std: 513912.63580081
# 200     2.94823909 min: 27258.38763095 mean: 27866.92164714 max: 28017.89622875 std: 117.68961754
# 400     5.86183596 min: 11705.43910807 mean: 11804.63457604 max: 11836.04115788 std:  26.26933776
# 600     8.77471495 min: 6429.72904393 mean: 6518.08894127 max: 6549.67166414 std:  23.85458380
# 800    11.68855000 min: 4166.90945365 mean: 4193.85843066 max: 4203.59509038 std:   8.11694057
# 1000    14.60286498 min: 3219.78244757 mean: 3232.31035987 max: 3236.77536934 std:   3.73641485
# 1200    17.51553702 min: 2762.39565719 mean: 2775.00924299 max: 2778.31438261 std:   2.86485073
# 1400    20.42746401 min: 2510.33808265 mean: 2515.10583791 max: 2516.61644355 std:   1.20060034
# 1600    23.34100795 min: 2332.94558782 mean: 2336.75451495 max: 2338.06891745 std:   0.99100384
# 1800    26.25433493 min: 2177.78690831 mean: 2179.61513294 max: 2180.21818920 std:   0.48796289
# 1999    29.15408492 min: 2068.40523087 mean: 2070.66318612 max: 2071.35438869 std:   0.54912489
# Results for dixon_and_price_function_1
# Min cost: 2068.40523087
# costs mean: 14278.9518025
# costs std: 54720.6428747

# %%
problem_name = 'rastrigin_function_1'
params = {
    'T': 5000,
    'mu': 500,
    'lambd': 1000,
    'chromosome_len': 30,
    'domain': (-5.12, 5.12),
    'K': 0.5,
    'F': rastrigin_function,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.02673292 min: 381.69537364 mean: 511.70003125 max: 555.00243808 std:  33.22898547
# 500     8.60202789 min:  98.89309163 mean:  98.95047110 max:  98.96594058 std:   0.01261237
# 1000    17.04599285 min:  96.98584393 mean:  97.00013094 max:  97.00468835 std:   0.00396519
# 1500    25.48031592 min:  95.73039111 mean:  95.74575239 max:  95.75006889 std:   0.00366061
# 2000    33.95273805 min:  93.67594228 mean:  93.69674017 max:  93.70376316 std:   0.00565811
# 2500    42.43294191 min:  88.32226687 mean:  88.37922476 max:  88.39578893 std:   0.01387424
# 3000    50.85919404 min:  85.81302726 mean:  85.81672350 max:  85.81786955 std:   0.00097881
# 3500    59.26778197 min:  85.75724868 mean:  85.75756495 max:  85.75764616 std:   0.00006729
# 4000    67.68178487 min:  85.71980482 mean:  85.72001779 max:  85.72008694 std:   0.00005928
# 4500    76.08964801 min:  85.66826350 mean:  85.66877818 max:  85.66889388 std:   0.00009995
# 4999    84.48749804 min:  85.57443035 mean:  85.57580925 max:  85.57620603 std:   0.00031273
# Results for rastrigin_function_1
# Min cost: 85.5744303495
# costs mean: 95.923250323
# costs std: 24.0726194892

# %%
problem_name = 'griewank_1'
params = {
    'T': 5000,
    'mu': 500,
    'lambd': 1000,
    'domain': (-600, 600),
    'chromosome_len': 40,
    'K': 0.6,
    'F': griewank_function,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.05020070 min: 632.32880415 mean: 978.62790157 max: 1093.89371064 std:  85.56087661
# 500     8.74538565 min: 100.52369853 mean: 101.02122570 max: 101.15816076 std:   0.12104850
# 1000    17.35672069 min:  54.40565861 mean:  54.65651841 max:  54.72185053 std:   0.05885508
# 1500    27.06413651 min:  34.68661310 mean:  34.79489780 max:  34.81541914 std:   0.01787190
# 2000    35.72491765 min:  26.23347829 mean:  26.31435509 max:  26.33040060 std:   0.01411807
# 2500    44.46848965 min:  17.57535293 mean:  17.67268056 max:  17.69579347 std:   0.01985788
# 3000    53.20519733 min:  10.15236022 mean:  10.18182365 max:  10.18940206 std:   0.00595231
# 3500    61.91406727 min:   9.13206041 mean:   9.13263917 max:   9.13280462 std:   0.00013461
# 4000    70.60800290 min:   9.10516482 mean:   9.10529378 max:   9.10534020 std:   0.00003784
# 4500    79.03276134 min:   8.96156578 mean:   8.96316129 max:   8.96355148 std:   0.00031451
# 4999    87.49536967 min:   8.88065423 mean:   8.88086363 max:   8.88092486 std:   0.00005156
# Results for griewank_1
# Min cost: 8.880654230404485
# costs mean: 43.036744694952546
# costs std: 75.02435163640881

# %%
problem_name = 'rastrigin_function_1'
params = {
    'T': 5000,
    'mu': 1500,
    'lambd': 3000,
    'chromosome_len': 30,
    'domain': (-5.12, 5.12),
    'K': 0.5,
    'F': rastrigin_function,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.07931209 min: 369.69605660 mean: 514.79087844 max: 558.90521681 std:  33.97941216
# 500    25.39689016 min: 107.45785457 mean: 107.47043415 max: 107.47338232 std:   0.00254612
# 1000    50.43379116 min: 106.37744032 mean: 106.38775376 max: 106.39027618 std:   0.00213239
# 1500    75.44390917 min: 105.40348210 mean: 105.40872316 max: 105.41017232 std:   0.00117986
# 2000   100.46793413 min: 104.97483072 mean: 104.97846095 max: 104.97928283 std:   0.00069778
# 2500   125.47845316 min: 104.79118070 mean: 104.79337820 max: 104.79392314 std:   0.00044873
# 3000   150.48528314 min: 104.52374147 mean: 104.52590238 max: 104.52642549 std:   0.00044864
# 3500   175.50516701 min: 104.22425980 mean: 104.22589617 max: 104.22633521 std:   0.00036890
# 4000   200.48439503 min: 104.09370979 mean: 104.09466760 max: 104.09493227 std:   0.00023715
# 4500   225.49739504 min: 104.00398387 mean: 104.00499494 max: 104.00522459 std:   0.00019846
# 4999   250.44286513 min: 103.87722841 mean: 103.87845778 max: 103.87879620 std:   0.00027456
# Results for rastrigin_function_1
# Min cost: 103.877228407
# costs mean: 107.341197134
# costs std: 14.4839370422

# %%
problem_name = 'schwefel_function_1'
params = {
    'T': 5000,
    'mu': 1000,
    'lambd': 2000,
    'chromosome_len': 30,
    'domain': (-500, 500),
    'K': 0.6,
    'F': schwefel_function,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.04476285 min: 9131.14521555 mean: 11196.80473876 max: 11820.90969788 std: 503.16284636
# 500    14.27100682 min: 5523.03319883 mean: 5525.74371845 max: 5526.38442565 std:   0.56777939
# 1000    28.48636794 min: 5023.11218888 mean: 5028.10099656 max: 5029.49195827 std:   1.10970115
# 1500    42.63377285 min: 4826.51941820 mean: 4827.14840876 max: 4827.32213677 std:   0.14676577
# 2000    56.77928686 min: 4765.02757090 mean: 4765.68569430 max: 4765.90832146 std:   0.18173252
# 2500    70.99559999 min: 4671.27818868 mean: 4672.21086697 max: 4672.44494735 std:   0.19668111
# 3000    85.10362697 min: 4652.06136859 mean: 4652.15597330 max: 4652.17914007 std:   0.01882267
# 3500    99.29320383 min: 4630.35098292 mean: 4630.61173892 max: 4630.68755014 std:   0.06569177
# 4000   113.48945093 min: 4577.06094679 mean: 4577.14591864 max: 4577.16929863 std:   0.02002732
# 4500   127.62018800 min: 4574.81577720 mean: 4574.82628827 max: 4574.82847849 std:   0.00189740
# 4999   141.72069502 min: 4572.14584332 mean: 4572.20375834 max: 4572.21499017 std:   0.00937353
# Results for schwefel_function_1
# Min cost: 4572.14584332
# costs mean: 4886.28466378
# costs std: 502.00898657
