# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from functools import partial, reduce

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from es import *
from functions import *
from plot import *

# %%
results = {}

# %%
problem_name = 'bohachevsky_1'
params = {
    'T': 100,
    'mu': 100,
    'lambd': 100,
    'chromosome_len': 2,
    'K': 0.6,
    'F': bohachevsky_function,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.00163913 min:   0.01460626 mean:   1.04849408 max:   2.02567062 std:   0.44260243
#  10     0.01026487 min:   0.00074783 mean:   0.03458703 max:   0.07243674 std:   0.01970701
#  20     0.01791239 min:   0.00000251 mean:   0.00039581 max:   0.00091440 std:   0.00023387
#  30     0.02378631 min:   0.00000011 mean:   0.00000386 max:   0.00000790 std:   0.00000223
#  40     0.03465176 min:   0.00000000 mean:   0.00000004 max:   0.00000010 std:   0.00000003
#  50     0.04417849 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  60     0.05232310 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  70     0.06159472 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  80     0.06733036 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  90     0.07342744 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  99     0.07831573 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
# Results for bohachevsky_1
# Min cost: 0.0
# costs mean: 0.0006461936518448819
# costs std: 0.002828832020537655

# %%
problem_name = 'dixon_and_price_function_1'
params = {
    'T': 2000,
    'mu': 200,
    'lambd': 400,
    'chromosome_len': 30,
#     'domain': (-10, 10),
    'K': 0.5,
    'F': dixon_and_price_function,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.02630019 min:  74.72497445 mean: 201.88730488 max: 360.41278441 std:  52.02458416
# 200     2.55701542 min:  66.42071872 mean: 190.22092159 max: 262.68542760 std:  44.12161093
# 400     5.22914886 min:  58.71525294 mean: 127.07280744 max: 158.23454650 std:  24.90788572
# 600     7.72005820 min:  40.86770182 mean:  70.04102944 max:  81.81303915 std:   8.64400621
# 800    10.23355293 min:  16.67430920 mean:  23.70984505 max:  25.34387561 std:   1.47561258
# 1000    12.73869324 min:  12.06823533 mean:  12.35285111 max:  12.49128196 std:   0.10680985
# 1200    15.23808432 min:  10.67762540 mean:  10.71803784 max:  10.72811535 std:   0.01013217
# 1400    17.82109213 min:  10.20283912 mean:  10.21412853 max:  10.21658468 std:   0.00209521
# 1600    20.43899417 min:   9.88449813 mean:   9.89169535 max:   9.89342688 std:   0.00151890
# 1800    23.13824821 min:   9.62900858 mean:   9.63241128 max:   9.63369922 std:   0.00102747
# 1999    25.81401634 min:   9.39803308 mean:   9.40408180 max:   9.40557378 std:   0.00128980
# Results for dixon_and_price_function_1
# Min cost: 9.398033078183538
# costs mean: 28.21820320043081
# costs std: 23.945964902229505

# %%
problem_name = 'rastrigin_function_1'
params = {
    'T': 5000,
    'mu': 500,
    'lambd': 1000,
    'chromosome_len': 30,
    'domain': (-5.12, 5.12),
    'K': 0.5,
    'F': rastrigin_function,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.02740097 min: 407.19903196 mean: 513.14239063 max: 555.58645750 std:  31.97013241
# 500     5.84512639 min:  93.96785598 mean:  94.07845502 max:  94.11244290 std:   0.02819314
# 1000    11.59782815 min:  89.41974245 mean:  89.43823536 max:  89.44463932 std:   0.00508843
# 1500    17.28524852 min:  86.63781915 mean:  86.66567092 max:  86.67360037 std:   0.00660789
# 2000    22.88537335 min:  83.60458929 mean:  83.62682521 max:  83.63433421 std:   0.00605343
# 2500    28.88027859 min:  79.17913952 mean:  79.21354050 max:  79.22558422 std:   0.00961636
# 3000    34.92329454 min:  76.52970360 mean:  76.53847053 max:  76.54118407 std:   0.00230909
# 3500    40.79368258 min:  76.12102552 mean:  76.12264561 max:  76.12305235 std:   0.00035648
# 4000    46.58836961 min:  76.00172748 mean:  76.00272305 max:  76.00292989 std:   0.00019280
# 4500    52.37126565 min:  75.89249778 mean:  75.89324186 max:  75.89345172 std:   0.00017038
# 4999    58.20524549 min:  75.78408181 mean:  75.78476987 max:  75.78496587 std:   0.00017122
# Results for rastrigin_function_1
# Min cost: 75.78408180668396
# costs mean: 86.1097036800099
# costs std: 23.035026336555422

# %%
problem_name = 'griewank_1'
params = {
    'T': 5000,
    'mu': 500,
    'lambd': 1000,
    'domain': (-600, 600),
    'chromosome_len': 40,
    'K': 0.6,
    'F': griewank_function,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.05020070 min: 632.32880415 mean: 978.62790157 max: 1093.89371064 std:  85.56087661
# 500     8.74538565 min: 100.52369853 mean: 101.02122570 max: 101.15816076 std:   0.12104850
# 1000    17.35672069 min:  54.40565861 mean:  54.65651841 max:  54.72185053 std:   0.05885508
# 1500    27.06413651 min:  34.68661310 mean:  34.79489780 max:  34.81541914 std:   0.01787190
# 2000    35.72491765 min:  26.23347829 mean:  26.31435509 max:  26.33040060 std:   0.01411807
# 2500    44.46848965 min:  17.57535293 mean:  17.67268056 max:  17.69579347 std:   0.01985788
# 3000    53.20519733 min:  10.15236022 mean:  10.18182365 max:  10.18940206 std:   0.00595231
# 3500    61.91406727 min:   9.13206041 mean:   9.13263917 max:   9.13280462 std:   0.00013461
# 4000    70.60800290 min:   9.10516482 mean:   9.10529378 max:   9.10534020 std:   0.00003784
# 4500    79.03276134 min:   8.96156578 mean:   8.96316129 max:   8.96355148 std:   0.00031451
# 4999    87.49536967 min:   8.88065423 mean:   8.88086363 max:   8.88092486 std:   0.00005156
# Results for griewank_1
# Min cost: 8.880654230404485
# costs mean: 43.036744694952546
# costs std: 75.02435163640881

# %%
problem_name = 'schwefel_function_1'
params = {
    'T': 1000,
    'mu': 1000,
    'lambd': 1000,
    'chromosome_len': 20,
    'domain': (-500, 500),
    'K': 0.6,
    'F': schwefel_function,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.03904223 min: 5529.39063959 mean: 7546.02513318 max: 8266.83280269 std: 571.15428951
# 100     0.90740800 min: 3570.76983718 mean: 3610.46463942 max: 3622.28181779 std:   9.85235907
# 200     1.74995160 min: 3443.32850675 mean: 3447.08514276 max: 3447.95119787 std:   0.71605768
