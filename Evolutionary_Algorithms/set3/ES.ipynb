# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from functools import partial, reduce

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from es import *
from functions import *
from plot import *

# %%
results = {}

# %%
problem_name = 'bohachevsky_1'
params = {
    'T': 100,
    'mu': 100,
    'lambd': 100,
    'chromosome_len': 2,
    'K': 0.6,
    'F': bohachevsky_function,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.02560210 min:   0.10006396 mean:   1.11784183 max:   1.91761271 std:   0.41381855
#  10     0.03399205 min:   0.00000202 mean:   0.00091111 max:   0.00172759 std:   0.00050867
#  20     0.04069805 min:   0.00000025 mean:   0.00001732 max:   0.00003630 std:   0.00001103
#  30     0.05100584 min:   0.00000000 mean:   0.00000019 max:   0.00000039 std:   0.00000011
#  40     0.06148696 min:   0.00000000 mean:   0.00000001 max:   0.00000001 std:   0.00000000
#  50     0.06778407 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  60     0.07345915 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  70     0.07915187 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  80     0.08454633 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
#  90     0.08992863 min:   0.00000000 mean:   0.00000000 max:   0.00000000 std:   0.00000000
# ...

# %%
problem_name = 'dixon_and_price_function_1'
params = {
    'T': 2000,
    'mu': 500,
    'lambd': 1000,
    'chromosome_len': 30,
    'domain': (-10, 10),
    'K': 0.5,
    'F': dixon_and_price,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.08306932 min: 854948.48372681 mean: 2410293.10114143 max: 3039986.28279556 std: 433105.60140000
# 200     6.67586756 min:   7.72603484 mean:   9.50341687 max:  10.00580944 std:   0.38485425
# 400    13.06870580 min:   0.51904277 mean:   0.52055441 max:   0.52097968 std:   0.00034127
# 600    19.30908728 min:   0.50004390 mean:   0.50005393 max:   0.50005708 std:   0.00000253
# 800    25.55019188 min:   0.50000004 mean:   0.50000004 max:   0.50000004 std:   0.00000000
# 1000    31.80635953 min:   0.50000000 mean:   0.50000000 max:   0.50000000 std:   0.00000000
# 1200    38.09845495 min:   0.50000000 mean:   0.50000000 max:   0.50000000 std:   0.00000000
# 1400    45.10227752 min:   0.50000000 mean:   0.50000000 max:   0.50000000 std:   0.00000000
# 1600    52.02202511 min:   0.50000000 mean:   0.50000000 max:   0.50000000 std:   0.00000000
# 1800    58.95362806 min:   0.50000000 mean:   0.50000000 max:   0.50000000 std:   0.00000000
# ...

# %%
problem_name = 'dixon_and_price_function_1'
params = {
    'T': 500,
    'mu': 500,
    'lambd': 1000,
    'chromosome_len': 100,
    'domain': (-10, 10),
    'K': 0.5,
    'F': dixon_and_price,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.19455957 min: 22292537.31011818 mean: 33204689.15478847 max: 37461964.44757847 std: 3101868.62311745
#  50     5.51720190 min: 3365425.28907861 mean: 3634089.58800953 max: 3694195.06373817 std: 49934.23787128
# 100    10.86226821 min: 1760813.16560833 mean: 1831562.69040785 max: 1852432.41604359 std: 19195.55533048
# 150    16.13838816 min: 1121292.43877154 mean: 1150568.06502938 max: 1157078.64367047 std: 5814.53306093
# 200    21.44588351 min: 840137.18228464 mean: 850193.31931742 max: 853474.72256228 std: 2750.83157030
# 250    26.83511949 min: 674285.89850906 mean: 684075.74799707 max: 687064.28021032 std: 2473.58926031
# 300    32.29332685 min: 558237.39742807 mean: 563744.00627993 max: 565356.49351485 std: 1422.68067778
# 350    37.79040837 min: 462944.36599368 mean: 467326.83812621 max: 468567.80820315 std: 1068.55627785
# 400    43.15365744 min: 386510.15986847 mean: 391504.78146751 max: 392694.23307048 std: 1030.75147970
# ...

# %%
problem_name = 'rastrigin_function_1'
params = {
    'T': 5000,
    'mu': 500,
    'lambd': 1000,
    'chromosome_len': 30,
    'domain': (-5.12, 5.12),
    'K': 0.5,
    'F': rastrigin_function,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.02673292 min: 381.69537364 mean: 511.70003125 max: 555.00243808 std:  33.22898547
# 500     8.60202789 min:  98.89309163 mean:  98.95047110 max:  98.96594058 std:   0.01261237
# 1000    17.04599285 min:  96.98584393 mean:  97.00013094 max:  97.00468835 std:   0.00396519
# 1500    25.48031592 min:  95.73039111 mean:  95.74575239 max:  95.75006889 std:   0.00366061
# 2000    33.95273805 min:  93.67594228 mean:  93.69674017 max:  93.70376316 std:   0.00565811
# 2500    42.43294191 min:  88.32226687 mean:  88.37922476 max:  88.39578893 std:   0.01387424
# 3000    50.85919404 min:  85.81302726 mean:  85.81672350 max:  85.81786955 std:   0.00097881
# 3500    59.26778197 min:  85.75724868 mean:  85.75756495 max:  85.75764616 std:   0.00006729
# 4000    67.68178487 min:  85.71980482 mean:  85.72001779 max:  85.72008694 std:   0.00005928
# 4500    76.08964801 min:  85.66826350 mean:  85.66877818 max:  85.66889388 std:   0.00009995
# ...

# %%
problem_name = 'griewank_1'
params = {
    'T': 3000,
    'mu': 500,
    'lambd': 1000,
    'domain': (-600, 600),
    'chromosome_len': 40,
    'K': 0.6,
    'F': griewank,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.01101875 min: 662.37121276 mean: 956.58409408 max: 1066.82955041 std:  82.84737026
# 300     1.42799973 min:  19.22525781 mean:  19.28088645 max:  19.29256351 std:   0.00996179
# 600     2.85499692 min:   1.55351828 mean:   1.56089640 max:   1.56312756 std:   0.00185178
# 900     4.21769452 min:   0.66671277 mean:   0.70874577 max:   0.71752312 std:   0.00777508
# 1200     5.58893919 min:   0.04175922 mean:   0.04188119 max:   0.04190558 std:   0.00002066
# 1500     6.95368099 min:   0.03689100 mean:   0.03731591 max:   0.03742992 std:   0.00009830
# 1800     8.32136559 min:   0.02537654 mean:   0.02538090 max:   0.02538201 std:   0.00000102
# 2100     9.68872476 min:   0.02462199 mean:   0.02462203 max:   0.02462204 std:   0.00000001
# 2400    11.07432604 min:   0.02461530 mean:   0.02461531 max:   0.02461532 std:   0.00000000
# 2700    12.44101405 min:   0.02461064 mean:   0.02461064 max:   0.02461064 std:   0.00000000
# ...

# %%
problem_name = 'griewank_1'
params = {
    'T': 5000,
    'mu': 1000,
    'lambd': 2000,
    'domain': (-600, 600),
    'chromosome_len': 80,
    'K': 1,
    'F': griewank,
}
results[problem_name] =  es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.04022241 min: 1732.05665664 mean: 2112.59827410 max: 2254.90224933 std: 110.08587603
# 500    11.34794068 min: 134.99883513 mean: 135.37390082 max: 135.48245545 std:   0.09215893
# 1000    22.22097564 min: 113.19396512 mean: 113.99478908 max: 114.10784758 std:   0.10725188
# 1500    33.06509733 min:  49.56836301 mean:  49.57156113 max:  49.57262607 std:   0.00087047
# 2000    43.83854771 min:  49.30998384 mean:  49.31307516 max:  49.31382710 std:   0.00067023
# 2500    54.68123364 min:  39.77928489 mean:  39.78293167 max:  39.78391997 std:   0.00081651
# 3000    65.78595614 min:  39.52308258 mean:  39.52309927 max:  39.52310305 std:   0.00000334
# 3500    76.60524011 min:   1.49580381 mean:   1.49719562 max:   1.49770240 std:   0.00040497
# 4000    87.44285607 min:   1.39609662 mean:   1.39611869 max:   1.39612397 std:   0.00000489
# 4500    98.12439013 min:   1.08958457 mean:   1.08964288 max:   1.08965732 std:   0.00001255
# ...

# %%
problem_name = 'rastrigin_function_1'
params = {
    'T': 5000,
    'mu': 1000,
    'lambd': 2000,
    'chromosome_len': 30,
    'domain': (-5.12, 5.12),
    'K': 10,
    'F': rastrigin,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.09165740 min: 352.59838925 mean: 511.95367563 max: 557.84834229 std:  35.15081550
# 500     3.60792351 min:  63.35294519 mean:  63.35294529 max:  63.35294531 std:   0.00000002
# 1000     7.11932015 min:  63.35294126 mean:  63.35294126 max:  63.35294126 std:   0.00000000
# 1500    10.55641961 min:  63.35162770 mean:  63.35162770 max:  63.35162770 std:   0.00000000
# Results for rastrigin_function_1
# Min cost: 0.0
# costs mean: 28.50477027084143
# costs std: 40.81890232570759

# %%
problem_name = 'rastrigin_function_1'
params = {
    'T': 5000,
    'mu': 1500,
    'lambd': 3000,
    'chromosome_len': 50,
    'domain': (-5.12, 5.12),
    'K': 0.8,
    'F': rastrigin,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.20317817 min: 687.67525367 mean: 887.18665428 max: 948.95693346 std:  46.34480930
# 500    22.26740265 min: 363.88236809 mean: 363.96655680 max: 363.98700353 std:   0.01726219
# 1000    44.22056532 min: 351.12639784 mean: 351.26109635 max: 351.28719492 std:   0.02237858
# 1500    66.24097872 min: 340.05995078 mean: 340.14149988 max: 340.16005988 std:   0.01566620
# 2000    88.89333177 min: 333.34890099 mean: 333.39426016 max: 333.40488058 std:   0.00943394
# 2500   111.90597796 min: 322.01445457 mean: 322.25361142 max: 322.32070792 std:   0.05303118
# 3000   134.34074116 min: 301.57300050 mean: 301.65681782 max: 301.67281812 std:   0.01429559
# 3500   156.81527567 min: 288.94095474 mean: 289.04075145 max: 289.05775523 std:   0.01567449
# 4000   179.40169716 min: 274.40263436 mean: 274.43697633 max: 274.44658123 std:   0.00781937
# 4500   202.93515372 min: 271.03406355 mean: 271.05657238 max: 271.06159549 std:   0.00410511
# ...

# %%
problem_name = 'schwefel_function_1'
params = {
    'T': 5000,
    'mu': 1000,
    'lambd': 2000,
    'chromosome_len': 30,
    'domain': (-500, 500),
    'K': 0.6,
    'F': schwefel_function,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.04476285 min: 9131.14521555 mean: 11196.80473876 max: 11820.90969788 std: 503.16284636
# 500    14.27100682 min: 5523.03319883 mean: 5525.74371845 max: 5526.38442565 std:   0.56777939
# 1000    28.48636794 min: 5023.11218888 mean: 5028.10099656 max: 5029.49195827 std:   1.10970115
# 1500    42.63377285 min: 4826.51941820 mean: 4827.14840876 max: 4827.32213677 std:   0.14676577
# 2000    56.77928686 min: 4765.02757090 mean: 4765.68569430 max: 4765.90832146 std:   0.18173252
# 2500    70.99559999 min: 4671.27818868 mean: 4672.21086697 max: 4672.44494735 std:   0.19668111
# 3000    85.10362697 min: 4652.06136859 mean: 4652.15597330 max: 4652.17914007 std:   0.01882267
# 3500    99.29320383 min: 4630.35098292 mean: 4630.61173892 max: 4630.68755014 std:   0.06569177
# 4000   113.48945093 min: 4577.06094679 mean: 4577.14591864 max: 4577.16929863 std:   0.02002732
# 4500   127.62018800 min: 4574.81577720 mean: 4574.82628827 max: 4574.82847849 std:   0.00189740
# ...

# %%
problem_name = 'schwefel_function_1'
params = {
    'T': 5000,
    'mu': 1000,X
    'lambd': 2000,
    'chromosome_len': 10,
    'domain': (-500, 500),
    'K': 0.6,
    'F': schwefel_function,
}
results[problem_name] = es_mu_plus_lambda(**params)
plot_es_results(problem_name, **results[problem_name])
# Out:
#   0     0.03193498 min: 2333.73455555 mean: 3406.86440432 max: 3793.99757878 std: 299.93007645
# 500     7.72532058 min: 1606.33554211 mean: 1606.62002415 max: 1606.68518600 std:   0.05359308
# 1000    15.44723821 min: 1125.28748064 mean: 1125.28963411 max: 1125.29051798 std:   0.00065226
# 1500    22.49905896 min: 1125.28610686 mean: 1125.28610686 max: 1125.28610686 std:   0.00000000
# 2000    29.48584795 min: 1125.28610686 mean: 1125.28610686 max: 1125.28610686 std:   0.00000000
# 2500    36.56240416 min: 1125.28610686 mean: 1125.28610686 max: 1125.28610686 std:   0.00000000
# 3000    43.65769076 min: 1125.28610686 mean: 1125.28610686 max: 1125.28610686 std:   0.00000000
# 3500    50.69605064 min: 1125.28610686 mean: 1125.28610686 max: 1125.28610686 std:   0.00000000
# 4000    57.97783065 min: 1125.28610686 mean: 1125.28610686 max: 1125.28610686 std:   0.00000000
# 4500    65.03165317 min: 1125.28610686 mean: 1125.28610686 max: 1125.28610686 std:   0.00000000
# ...
